# %%
class Restaurent:
    def __init__(self):
        self.food = {}
        self.ordered_id = len(self.food)+1
        self.ordered_item =[]
        self.user_details = {}
        self.admin_details = {}

# Admin functions        

    def add_food_items(self):
        self.name = input("Enter name of the food: ")
        self.quantity = input("Enter the quantity of food: ")
        self.price = float(input("Enter the price in Rs: "))
        self.stock = input("Enter the available stock in kg/ml/pieces:")
        self.discount = int(input("Enter the discount value in Rs :" ))
        self.food_item = {"Name": self.name, "Quantity": self.quantity, "Price": self.price, "discount in Rs/-": self.discount, "Stock": self.stock}
        self.food_id = len(self.food) + 1
        self.food[self.food_id] = self.food_item
        print("Item added successfully !! \n")
        print("Newly added food items :", self.food,"\n")
    
    def remove_food_items(self):
        print("Make Sure you want to delete food_item")
        del self.food[int(input("Enter the food_id you want to delete: "))]
        print("The food_item is deleted successfully \n")
        print("Remaining food items list :", self.food)
                
    def edit_food_items(self):
        x = int(input("Enter the food id you want to update : \n"))
        for i in self.food.keys():
            print("1. Update Food Name \n2. Update Quantity of Food \n3. Update Price \n4. Update discount \n5. Update Stock \n")
            y = input("Enter the ID of the food: ")
            if y == "1":
                self.food[x]["Name"] = input("Update Food Name you want: ")
                print("The Food Name Updated \n")
            elif y == "2":
                self.food[x]["Quantity"] = int(input("update the Quantity: "))
                print("Quantity updated \n")
            elif y == "3":
                self.food[x]["Price"] = int(input("Update Price: "))
                print("Price Updated \n")
            elif y == "4":
                self.food[x]["discount"] = int(input("Update discount: "))
                print("Discount Updated \n")
            elif y == "5":
                self.food[x]["Stock"] = int(input("Update Stock: "))
                print("Stock Updated \n")
            else:
                print("  Incorrect Food id \n")
        else:
            print("Food item is updated successfully \n", self.food)
        
    def view_food_list(self):
        print("\nList of food items : \n")
        if len(self.food) != 0:
            for j in self.food:
                print("\nFood id :", {j})
                for k in self.food[j]:
                    print(k, ":", self.food[j][k])
        else:
            print("No food items were added!!")
            print("Please Add food items first !! \n")
                
# Functionalities of the user                
    def Register(self):
        self.username = input("Enter the name of the user :")
        self.user_phone_no = int(input("Enter the Phone No. :"))
        self.user_email_id = input("Enter the email_id of the user:")
        self.user_password = input("Enter the password :")
        self.user_details = {"Name":self.username, "Phone No.": self.user_phone_no, "Email": self.user_email_id, "Password": self.user_password}
        print("Registration is Succesfull!! \n")
        print("Welcome to you", self.username)
        print("Please Sign In")
        
    def login(self):
            user_email_id = input("Enter your Email Id :")
            password = input("Enter your Password :")
            if len(self.user_details) != 0:
                if user_email_id == self.user_details["Email"]:
                    if password == self.user_details["Password"]:
                        print("Congratulations, You have Successfully login")
                        while True:
                            print("select from the options \n 1.Place Order \n2.Check Order_history \n3. Update profile \n4. Exit")
                            k = input()
                            if k == "1":
                                self.place_order()
                            elif k == "2":
                                self.order_history()
                            elif k == "3":
                                self.update_user_profile()
                            elif k == "4":
                                break
                            else:
                                break
                            
                    else:
                        print("Incorrect Username or Password.\n Please Try again")
                else:
                    print("invalid")
            else:
                print("There is No Account found with this Email_id.\n Please Create an Account \n")
                self.Register()
                print("Your Account is created Successfully \n")
    def place_order(self):
        if len(self.food) != 0:
            menu = []
            for items in self.food:
                menu.append([self.food[items]["Name"], self.food[items]["Quantity"], self.food[items]["Price"]])
            for i in menu:
                print(len(i[1]), i)
            while True:
                x = input("Enter Your Key :")
                if x == "1":
                    print("Enter the food id")
                    y = input("Your Choice")
                    for i in y:
                        z = int(i)
                        if z<=len(menu):
                            self.ordered_item.append(menu[z-1])
                        else:
                            print("Sorry not available :",z)
                    print("list of food items you have selected : \n",z)
                    for j in self.ordered_item:
                        print(j)
                elif x == "2":
                    break
                else:
                    print("invalid")
        else:
            print("sorry no food items are available")
                    
    def order_history(self):
        print("list of Previous ordered :")
        for i in self.ordered_item:
            print(i)
        
    def update_user_profile(self):
        while True:
            print("Select Below Options to update Your Profile \n")
            print("1.Name \n2. Phone No \n3. Email Id \n4. Password \n 5. Exit \n")
            x = input()
            if x == "1":
                self.user_details["User Name"] = input("Update Name : ")
                print("Successful")
            elif x == "2":
                self.user_details["Phone No"] = int(input("Update Phone No. :"))
                print("Successful")
            elif x == "3":
                self.user_details["email_id"] = input("Update Your Email_id :")
                print("Successful")
            elif x == "4":
                self.user_details["Password"] = input("Update Password :")
                print("Successful")
            elif x == "5":
                break
            else:
                print("Something went wrong")
                
            if x in ["1", "2", "3", "4", "5"]:
                for i in self.user_details:
                    print("User updated details :\n",x)
                    
try:
    def main():
        obj = Restaurent()
        print("Welcome To RSK Restaurent")
        while True:
            print("1. Admin \n2. User \n3. Exit \n")
            x = input()
            if x == "1":
                while True:
                    print("1. Add New Food Items \n2. Edit Food Items \n3. View Food Items \n4. Remove Food items \n5. Exit ")
                    y = input()
                    if y == "1":
                        obj.add_food_items()
                    elif y == "2":
                        obj.edit_food_items()
                    elif y == "3":
                        obj.view_food_list()
                    elif y == "4":
                        obj.remove_food_items()
                    elif y == "5":
                        break
                    else:
                        print("Invalid")
            elif x == "2":
                  while True:
                        print("\n Select from the Below Options")
                        print("1. Register \n2. Login \n3. Exit \n")
                        y = input()
                        if y == "1":
                            obj.Register()
                        elif y == "2":
                            obj.login()
                        elif y == "3":
                            break
                        else:
                            print("invalid")
            elif x == "3":
                break
        
            else:
                print("Invalid Number you have selected")
                
            
except exception as e: 
    print("Give correct values")
              
if __name__=='__main__':
    main()

print("Visit again:-) \nStay Safe and Stay Helthy")
print("Thank You")
# Out:
# Welcome To RSK Restaurent
# 1. Admin
# 2. User
# 3. Exit
#
# 1
# 1. Add New Food Items
# 2. Edit Food Items
# 3. View Food Items
# 4. Remove Food items
# 5. Exit
# 1
# Enter name of the food: Tandoori Chicken
# Enter the quantity of food: 4pieces
# Enter the price in Rs: 380
# Enter the available stock in kg/ml/pieces:20pieces
# Enter the discount value in Rs :40
# Item added successfully !!
#
# Newly added food items : {1: {'Name': 'Tandoori Chicken', 'Quantity': '4pieces', 'Price': 380.0, 'discount in Rs/-': 40, 'Stock': '20pieces'}}
#
# 1. Add New Food Items
# 2. Edit Food Items
# 3. View Food Items
# 4. Remove Food items
# 5. Exit
# 1
# Enter name of the food: Vegen Burger
# Enter the quantity of food: 1piece
# Enter the price in Rs: 280
# Enter the available stock in kg/ml/pieces:20pieces
# Enter the discount value in Rs :40
# Item added successfully !!
#
# ...
